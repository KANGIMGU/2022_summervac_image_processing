# %% [markdown]
# # 파이썬 기초

# %%
def zero_or_one(pixel: int) -> int:

# %%
print(f"픽셀 값이 255 이면, 이 픽셀은 {zero_or_one(255)} 이다.")
print(f"픽셀 값이 0 이면, 이 픽셀은 {zero_or_one(0)} 이다.")
print(f"픽셀 값이 30 이면, 이 픽셀은 {zero_or_one(30)} 이다.")
# Out:
# 픽셀 값이 255 이면, 이 픽셀은 1 이다.
# 픽셀 값이 0 이면, 이 픽셀은 0 이다.
# 픽셀 값이 30 이면, 이 픽셀은 -1 이다.

# %%
print(f"픽셀 값이 'a' 이면, 이 픽셀은 {zero_or_one('a')} 이다.")
# Out:
# 픽셀 값이 'a' 이면, 이 픽셀은 -1 이다.

# %% [markdown]
# # 파이썬 배열 기초

# %%
import numpy as np

# %%
# Out:
# (2, 3)

# %%
# Out:
# (2, 2)

# %%
# (0, 0) 좌표 값 보기
# Out:
# [255   0]

# %%
# (0, 0) 좌표 값 보기
# Out:
# [255   1]

# %%
def zero_or_one2(pixels: np.array) -> int:

# %%
arr = np.array([6, 3, 1, 7, 8, 4])

print(f"arr[0:] - {}")
print(f"arr[1:3] - {}")
print(f"arr[:-1] - {}")
print(f"arr[-3:-1] - {}")
print(f"arr[-5:5] - {}")
print(f"arr[-3:] - {}")
# Out:
# arr[0:] - [6 3 1 7 8 4]
# arr[1:3] - [3 1]
# arr[:-1] - [6 3 1 7 8]
# arr[-3:-1] - [7 8]
# arr[-5:5] - [3 1 7 8]
# arr[-3:] - [7 8 4]

# %%
# Out:
# 1
